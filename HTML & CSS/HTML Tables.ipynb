# %% [markdown]
# ### Create a table
#
# Before we can put data in the table we have to create its structure
# TABLE tag gives theframe
# TR tags are the rows in the table
# within the rows the data must be added in each cell with TD
# The headers can be myde by the table heading TH tags, they must be the children or a TR
# TH tags has an attribute indicating whether they are for a column or a row (scope = "col" or scope = "row")
# In older HTML versions the border was added by the border attribute in the table tag
# Nowadays we use css for formatting tables too
# If you want to allow a TD element to span more columns you can use the colspan attribute (<td colspan="2" ... the integer >=1)
# Also rows can span into multiple rows with <td rowspan="2" ... integer>=1
#
# If the table grows too long/big we can separate the body between TBODY tags and
# put the heading into THEAD tags and
# put the footer into TFOOT tags
#
# You can style your page with CSS, here is an example for that.
# You need to link the css to the page in the HEAD:
# <link href="style.css" type="text/css" rel="stylesheet">

# %% [markdown]
# body {
#   background: #EEE;
#   margin: 0;
#   padding: 0;
# }
#
# /* Navigation */
#
# .navigation {
#   box-sizing: border-box;
#   background-color: #3587A4;
#   overflow: auto;
#   padding: 18px 50px;
#   position: relative;
#   top: 0;
#   width: 100%;
#   z-index: 999;
# }
#
# ul {
#   padding: 0;
#   margin: 0;
# }
#
# li {
#   color: #FFF;
#   display: inline-block;
#   font-family: 'Oxygen', sans-serif;
#   font-weight: 300;
#   letter-spacing: 2px;
#   margin: 0;
#   padding: 20px 18px 10px 18px;
#   text-transform: uppercase;
# }
#
# .active {
#   color: #88CCF1;
# }
#
# /* Table */
#
# table {
#   height: 40%;
#   left: 10%;
#   margin: 20px auto;
#   overflow-y: scroll;
#   position: static;
#   width: 80%;
# }
#
# thead th {
#   background: #88CCF1;
#   color: #FFF;
#   font-family: 'Lato', sans-serif;
#   font-weight: 100;
#   letter-spacing: 2px;
#   text-transform: uppercase;
# }
#
# tr {
#   background: #f4f7f8;
#   border-bottom: 1px solid #FFF;
#   margin-bottom: 5px;
# }
#
# th, td {
#   font-family: 'Lato', sans-serif;
#   font-weight: 400;
#   padding: 20px;
#   font-size: 18px;
#   text-align: left;
#   width: 33.3333%;
# }
#
# .search {
#   background-color: #FFF;
#   border: 1px solid #DDD;
#   border-radius: 3px;
#   color: #AAA;
#   padding: 20px;
#   margin: 50px auto 0px auto;
#   width: 77%;
# }

# %% [markdown]
# <link href="style.css" type="text/css" rel="stylesheet">
# <table>
#     <thead>
#         <tr>
#             <th scope="col">Company Name</th>
#             <th scope="col">Number of Items to Ship</th>
#             <th scope="col">Next Action</th>
#         </tr>
#     </thead>
#      <tbody>
#         <tr>
#             <td>Adam’s Greenworks</td>
#             <td>14</td>
#             <td>Package Items</td>
#         </tr>
#         <tr>
#           <td>Davie's Burgers</td>
#           <td>2</td>
#           <td>Send Invoice</td>
#         </tr>
#         <tr>
#           <td>Baker's Bike Shop</td>
#           <td>3</td>
#           <td>Send Invoice</td>
#         </tr>
#         <tr>
#           <td>Miss Sally's Southern</td>
#           <td>4</td>
#           <td>Ship</td>
#         </tr>
#         <tr>
#           <td>Summit Resort Rentals</td>
#           <td>4</td>
#           <td>Ship</td>
#         </tr>
#         <tr>
#           <td>Strike Fitness</td>
#           <td>1</td>
#           <td>Enter Order</td>
#         </tr>
#     <tfoot>
#         <tr>
#             <td>Total</td>
#             <td>28</td>
#         </tr>
#     </tfoot>
#     </tbody>
# </table>

# %% [markdown]
# <table>
#   <tr> <!-- Row 1 -->
#     <th></th>
#     <th>Saturday</th>
#     <th>Sunday</th>
#   </tr>
#   <tr> <!-- Row 2 -->
#     <th>Morning</th>
#     <td rowspan="2">Work</td>
#     <td rowspan="3">Relax</td>
#   </tr>
#   <tr> <!-- Row 3 -->
#     <th>Afternoon</th>
#   </tr>
#   <tr> <!-- Row 4 -->
#     <th>Evening</th>
#     <td>Dinner</td>
#   </tr>
# </table>
